# %% [markdown]
# <a href="https://colab.research.google.com/github/Nathanael126/Intelligent-Systems-Code-Results/blob/main/Image_Generators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Downloading and importing libraries

# %%
# Installations

from IPython.display import clear_output
# %pip install openai
# %pip install stability-sdk
clear_output()

# %%
# Importing libraries

import openai
import glob
import urllib
import urllib.request
import os
import io
import warnings
import stability_sdk.interfaces.gooseai.generation.generation_pb2 as generation
from urllib.request import urlopen
from matplotlib.pyplot import imread
from IPython.display import Image, display
from google.colab import drive
from stability_sdk import client
from PIL import Image as PILImage

# %% [markdown]
# # Dall-E part

# %%
# Dall-e generates 4 images using its own model

openai.api_key = "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"

prompt = "Mega Pikachu" #@param{type:"string"}
model = "image-alpha-001"
num_images = 4 #@param{type:"number"}
size = "512x512" #@param{type:"string"}

Picture = openai.Image.create(model=model, prompt=prompt, n=num_images, size=size)
Picture_data = Picture['data']
Picture_url = []

for i in Picture_data:
  Picture_url.append(i['url'])

images = [Image(url=url, height=250, width=250) for url in Picture_url]

for i in Picture_url:
  print(i)
display(*images)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-vzLdij8zbqYYcqDDXqhwi8P4/user-hY67P6hXSxYGdyl3IUqtv6g1/img-CrZueKL5YAeIZ0OZ8PNft9JR.png?st=2023-01-12T00%3A49%3A37Z&se=2023-01-12T02%3A49%3A37Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-01-11T23%3A39%3A26Z&ske=2023-01-12T23%3A39%3A26Z&sks=b&skv=2021-08-06&sig=bVo1koZPBOQ2NkzsEsfjkwXR%2BMB18rXZidO26JFpMCs%3D
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-vzLdij8zbqYYcqDDXqhwi8P4/user-hY67P6hXSxYGdyl3IUqtv6g1/img-4Y7NVDf6YWU4MAdxeovkRzjn.png?st=2023-01-12T00%3A49%3A37Z&se=2023-01-12T02%3A49%3A37Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-01-11T23%3A39%3A26Z&ske=2023-01-12T23%3A39%3A26Z&sks=b&skv=2021-08-06&sig=XyTnQs6wnL/sooVrZUfpbspoFo1jMuxZHh8%2B0Ix6puc%3D
# ...

# %% [markdown]
# # Stable diffusion part
#
# Please use sparingly, or use your own stability.ai account to generate images. Due to a limited budget, we cannot generate a lot of images using Stable Diffusion, if you would like to use your own account, replace the API key

# %%
os.environ['STABILITY_HOST'] = 'grpc.stability.ai:443'
os.environ['STABILITY_KEY'] = 'sk-RizSWs7tvg1Osx9aoAqqkAn3WjelJ6FT5S7lsqYAwBG0o9Xo'

# %%
# Set up our connection to the API.
stability_api = client.StabilityInference(
    key=os.environ['STABILITY_KEY'], # API Key reference.
    verbose=True, # Print debug messages.
    engine="stable-diffusion-v1-5", # Set the engine to use for generation. 
    # Available engines: stable-diffusion-v1 stable-diffusion-v1-5 stable-diffusion-512-v2-0 stable-diffusion-768-v2-0 stable-inpainting-v1-0 stable-inpainting-512-v2-0
)
# Out:
# INFO:stability_sdk.client:Opening channel to grpc.stability.ai:443
# INFO:stability_sdk.client:Channel opened to grpc.stability.ai:443

# %%
prompt= "Mega Pikachu" #@param{type:"string"}
steps=30 #@param{type:"integer"}
cfg_scale=7.0 #@param{type:"number"}
width=512 #@param{type:"number"}
height=512 #@param{type:"number"}
samples=4 #@param{type:"number"}

answers = stability_api.generate(
    prompt=prompt,
    steps=steps, 
    cfg_scale=cfg_scale,
    width=width,
    height=height,
    samples=samples,
    sampler=generation.SAMPLER_K_DPMPP_2M
)
for resp in answers:
    for artifact in resp.artifacts:
        if artifact.finish_reason == generation.FILTER:
            warnings.warn(
                "Your request activated the API's safety filters and could not be processed."
                "Please modify the prompt and try again.")
        if artifact.type == generation.ARTIFACT_IMAGE:
            img = PILImage.open(io.BytesIO(artifact.binary))
            display(img)
# Out:
# INFO:stability_sdk.client:Sending request.
# INFO:stability_sdk.client:Got keepalive e28f086e-5d8d-4590-9d25-d89e3fd8c2a8 in 0.22s
# INFO:stability_sdk.client:Got keepalive ee0e0463-08f3-4d17-8152-49a532913cd3 in 0.00s
# INFO:stability_sdk.client:Got keepalive ea1f18ed-a417-44fd-b938-bec81e99fe97 in 0.01s
# INFO:stability_sdk.client:Got keepalive 2c3ddf2c-68cb-457d-84de-e9bf58955012 in 0.00s
# INFO:stability_sdk.client:Got keepalive ea1f18ed-a417-44fd-b938-bec81e99fe97 in 1.95s
# INFO:stability_sdk.client:Got keepalive e28f086e-5d8d-4590-9d25-d89e3fd8c2a8 in 0.05s
# INFO:stability_sdk.client:Got ea1f18ed-a417-44fd-b938-bec81e99fe97 with ['ARTIFACT_IMAGE', 'ARTIFACT_CLASSIFICATIONS', 'ARTIFACT_LATENT'] in 0.08s
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7FD16E2AF730>
# INFO:stability_sdk.client:Got e28f086e-5d8d-4590-9d25-d89e3fd8c2a8 with ['ARTIFACT_IMAGE', 'ARTIFACT_CLASSIFICATIONS', 'ARTIFACT_LATENT'] in 0.00s
# ...
